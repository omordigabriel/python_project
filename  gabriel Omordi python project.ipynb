# %% [markdown]
#  # PROJECT
#  ### BY GABRIEL OMORDI

# %%
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
import seaborn as sns, statistics as stats

# %%
df = pd.read_csv('datasets/africa_food_prices.csv')
df
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 956779 entries, 0 to 956778
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Unnamed: 0          956779 non-null  int64
#  1   country_id          956779 non-null  float64
#  2   country             956779 non-null  object
#  3   state_id            956779 non-null  int64
#  4   state               830101 non-null  object
#  5   market_id           956779 non-null  int64
#  6   market              956779 non-null  object
#  7   produce_id          956779 non-null  int64
#  8   produce             956779 non-null  object
#  9   currency_id         956779 non-null  float64
#  10  currency            956779 non-null  object
#  11  pt_id               956779 non-null  int64
#  12  market_type         956779 non-null  object
#  13  um_unit_id          956779 non-null  int64
#  14  quantity            956779 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
df.state.value_counts().unique
# Out:
# <bound method Series.unique of state
# North/Amajyaruguru     34770
# South/Amajyepfo        31610
# East/Iburasirazuba     30805
# West/Iburengerazuba    30032
# Yobe                   15671
#                        ...
# Tiris-Zemmour             29
# Toliara                   24
# Kabale                    24
# Lunda Norte               24
# Semenawi Keih Bahri       18
# Name: count, Length: 311, dtype: int64>

# %%
df.state.dtype
# Out:
# dtype('O')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                 126678
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# 0           5       KG      4  2015   90.0                 NaN
# 1           5       KG      5  2015   96.0                 NaN

# %%
df[df['state'].isna()==1]
# Out:
#         Unnamed: 0  country_id    country  state_id state  market_id  \
# 140847      398362        50.0       Chad         0   NaN       1965
# 140848      398363        50.0       Chad         0   NaN       1965
# 140849      398364        50.0       Chad         0   NaN       1965
# 140850      398365        50.0       Chad         0   NaN       1965
# 140851      398366        50.0       Chad         0   NaN       1965
# ...            ...         ...        ...       ...   ...        ...
# 889628     1713307       235.0  Swaziland      2784   NaN       2654
# 889629     1713308       235.0  Swaziland      2784   NaN       2654
# 889630     1713309       235.0  Swaziland      2784   NaN       2654
# 889631     1713310       235.0  Swaziland      2784   NaN       2654
# 889632     1713311       235.0  Swaziland      2784   NaN       2654
#
#                   market  produce_id                   produce  currency_id  \
# ...

# %%
df1 = df.fillna({'state':'None'})
df1
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                 0
# country_id                 0
# country                    0
# state_id                   0
# state                      0
# market_id                  0
# market                     0
# produce_id                 0
# produce                    0
# currency_id                0
# currency                   0
# pt_id                      0
# market_type                0
# um_unit_id                 0
# quantity                   0
# month                      0
# year                       0
# price                      0
# mp_commoditysource    956779
# dtype: int64

# %%
df2 = df1.drop(['mp_commoditysource'], axis=1)
df2
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956774     2050633       271.0  Zimbabwe      3444  Midlands       5594
# 956775     2050634       271.0  Zimbabwe      3444  Midlands       5594
# 956776     2050635       271.0  Zimbabwe      3444  Midlands       5594
# 956777     2050636       271.0  Zimbabwe      3444  Midlands       5594
# 956778     2050637       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id                  produce  currency_id currency  \
# ...

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0     0
# country_id     0
# country        0
# state_id       0
# state          0
# market_id      0
# market         0
# produce_id     0
# produce        0
# currency_id    0
# currency       0
# pt_id          0
# market_type    0
# um_unit_id     0
# quantity       0
# month          0
# year           0
# price          0
# dtype: int64

# %%
df2[df2.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, country_id, country, state_id, state, market_id, market, produce_id, produce, currency_id, currency, pt_id, market_type, um_unit_id, quantity, month, year, price]
# Index: []

# %%
df2.country_id.dtype
# Out:
# dtype('float64')

# %%
df2.produce.value_counts().unique
# Out:
# <bound method Series.unique of produce
# Millet - Retail                     47476
# Rice (imported) - Retail            47022
# Sorghum - Retail                    44679
# Maize - Retail                      43073
# Maize (white) - Retail              33786
#                                     ...
# Millet (white) - Wholesale              1
# Potatoes (unica) - Retail               1
# Kocho - Retail                          1
# Beans (haricot, red) - Wholesale        1
# Sorghum (biofortified) - Retail         1
# Name: count, Length: 457, dtype: int64>

# %%
df2.head()
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
# 2       15429         4.0  Algeria       344  Alger       1794  Algiers
# 3       15430         4.0  Algeria       344  Alger       1794  Algiers
# 4       15431         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
# 2          52  Rice - Retail          0.0      DZD     15      Retail
# 3          52  Rice - Retail          0.0      DZD     15      Retail
# 4          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price
# 0           5       KG      4  2015   90.0
# ...

# %%
df2.market_type.value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='market_type'>

# %% [markdown]
# THIS SHOWS MOST COUNTRIES IN AFRICA ARE MAINLY RETAILERS,
# THEY MOSTLY IMPORT FOODS.

# %%
prodR = df2[df2['produce'] =='Rice - Retail']
prodR
# Out:
#         Unnamed: 0  country_id   country  state_id     state  market_id  \
# 0            15427         4.0   Algeria       344     Alger       1794
# 1            15428         4.0   Algeria       344     Alger       1794
# 2            15429         4.0   Algeria       344     Alger       1794
# 3            15430         4.0   Algeria       344     Alger       1794
# 4            15431         4.0   Algeria       344     Alger       1794
# ...            ...         ...       ...       ...       ...        ...
# 956720     2050579       271.0  Zimbabwe      3444  Midlands       5585
# 956721     2050580       271.0  Zimbabwe      3444  Midlands       5585
# 956722     2050581       271.0  Zimbabwe      3444  Midlands       5585
# 956723     2050582       271.0  Zimbabwe      3444  Midlands       5585
# 956769     2050628       271.0  Zimbabwe      3444  Midlands       5594
#
#             market  produce_id        produce  currency_id currency  pt_id  \
# ...

# %%
countR=prodR.produce.value_counts()
countR
# Out:
# produce
# Rice - Retail    15513
# Name: count, dtype: int64

# %%
# Example: Top 5 products by total sales
top_products = df1.groupby('produce')['country'].sum().sort_values(ascending=False).head(5)
print("Top 5 Products by Total Sales:\n", top_products)
# Out:
# Top 5 Products by Total Sales:
#  produce
# Fish (kapenta) - Retail                   ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Oil (vegetable, fortified) - Retail       ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Sugar (white, fortified) - Retail         ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Wheat flour (fortified) - Retail          ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Maize meal (white, fortified) - Retail    ZimbabweZimbabweZimbabweZimbabweZimbabweZimbab...
# Name: country, dtype: object

# %%
df1.head(2)
# Out:
#    Unnamed: 0  country_id  country  state_id  state  market_id   market  \
# 0       15427         4.0  Algeria       344  Alger       1794  Algiers
# 1       15428         4.0  Algeria       344  Alger       1794  Algiers
#
#    produce_id        produce  currency_id currency  pt_id market_type  \
# 0          52  Rice - Retail          0.0      DZD     15      Retail
# 1          52  Rice - Retail          0.0      DZD     15      Retail
#
#    um_unit_id quantity  month  year  price  mp_commoditysource
# 0           5       KG      4  2015   90.0                 NaN
# 1           5       KG      5  2015   96.0                 NaN

# %% [markdown]
# # RETAIL EVALUATION BY FOOD PRODUCT

# %%
df1['produce'].value_counts().head(5)
# Out:
# produce
# Millet - Retail             47476
# Rice (imported) - Retail    47022
# Sorghum - Retail            44679
# Maize - Retail              43073
# Maize (white) - Retail      33786
# Name: count, dtype: int64

# %%
df1['produce'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='produce'>

# %% [markdown]
# MILLET IS THE HIGHEST RETAILED FOOD FOLLOWED BY RICE

# %%
top_5_countries = df2['country'].value_counts().head(5)
top_5_countries
# Out:
# country
# Rwanda     137746
# Mali        73843
# Burundi     60921
# Gambia      56971
# Niger       54974
# Name: count, dtype: int64

# %%
df1.market_type.value_counts()
# Out:
# market_type
# Retail       885918
# Wholesale     70613
# Producer        248
# Name: count, dtype: int64

# %%
mkp = df2[df2['market_type'] == 'Producer']
mkp
# Out:
#         Unnamed: 0  country_id     country  state_id            state  \
# 384613     1019278       150.0  Madagascar      1881       Atsinanana
# 384614     1019279       150.0  Madagascar      1881       Atsinanana
# 384615     1019280       150.0  Madagascar      1881       Atsinanana
# 384616     1019281       150.0  Madagascar      1881       Atsinanana
# 384617     1019282       150.0  Madagascar      1881       Atsinanana
# ...            ...         ...         ...       ...              ...
# 393411     1028076       150.0  Madagascar    899999  Alaotra Mangoro
# 393412     1028077       150.0  Madagascar    899999  Alaotra Mangoro
# 393413     1028078       150.0  Madagascar    899999  Alaotra Mangoro
# 393414     1028079       150.0  Madagascar    899999  Alaotra Mangoro
# 393415     1028080       150.0  Madagascar    899999  Alaotra Mangoro
#
#         market_id                    market  produce_id  \
# 384613        750       Atsinanana (Region)         203
# ...

# %%
countp = mkp['country'].value_counts().head()
countp
# Out:
# country
# Madagascar    248
# Name: count, dtype: int64

# %% [markdown]
# THE ONLY PRODUCING COUNTRY HERE IS MADAGASCAR

# %% [markdown]
# # WHOLESALE EVALUATION BY COUNTRIES

# %%
wsaler=df2[df2['market_type'] == 'Wholesale']
wsaler
# Out:
#         Unnamed: 0  country_id country  state_id    state  market_id  \
# 3065        185502        29.0   Benin       609  Alibori       1044
# 3066        185503        29.0   Benin       609  Alibori       1044
# 3067        185504        29.0   Benin       609  Alibori       1044
# 3068        185505        29.0   Benin       609  Alibori       1044
# 3069        185506        29.0   Benin       609  Alibori       1044
# ...            ...         ...     ...       ...      ...        ...
# 902012     1883640       253.0  Uganda     47082     Lira        263
# 902013     1883641       253.0  Uganda     47082     Lira        263
# 902014     1883642       253.0  Uganda     47082     Lira        263
# 902015     1883643       253.0  Uganda     47082     Lira        263
# 902016     1883644       253.0  Uganda     47082     Lira        263
#
#                   market  produce_id                produce  currency_id  \
# ...

# %%
countw=wsaler['country'].value_counts().head()
countw
# Out:
# country
# Ghana       18231
# Nigeria     17362
# Cameroon     9767
# Ethiopia     8003
# Kenya        4436
# Name: count, dtype: int64

# %% [markdown]
# THE TOP 5 WHOLESALE COUNTRIES IN AFRICA

# %%
wsaler['country'].value_counts().head().plot(kind='bar')
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# # YEAR EVALUATION

# %%
sns.histplot(df2["year"])
plt.show()

# %%
sns.histplot(mkp["year"])
plt.show()
